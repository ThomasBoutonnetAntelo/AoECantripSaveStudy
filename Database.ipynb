# %% [markdown]
# ## Database import & cleaning

# %%
#imports
import pandas as pd

# %% [markdown]
# ### 1.1 Database used
#
# First lets import a database of monsters. Luckily for us some people over Kaggle have already scraped a simple list at:
#
# https://www.kaggle.com/datasets/travistyler/dnd-5e-monster-manual-stats?resource=download&select=cleaned_monsters_basic.csv

# %%
file_url = "https://www.kaggle.com/datasets/travistyler/dnd-5e-monster-manual-stats?resource=download&select=cleaned_monsters_basic.csv"
file = "cleaned_monsters_basic.csv"

# %%
#This database has so many columns we don't need. lets rename them and take only what we need

columns = ['0', 'name', 'size', 'monster_type', 'alignment', 'ac', 'hp',
       'str', 'str_mod', 'dex', 'dex_mod', 'con', 'con_mod', 'int',
       'int_mod', 'wis', 'wis_mod', 'cha', 'cha_mod', 'senses', 'languages',
       'cr', 'str_save', 'dex_save', 'con_save', 'int_save', 'wis_save',
       'cha_save', 'speed', 'swim', 'fly', 'climb', 'burrow',
       'number_legendary_actions', 'history', 'perception', 'stealth',
       'persuasion', 'insight', 'deception', 'arcana', 'religion',
       'acrobatics', 'athletics', 'intimidation']

useful_columns  = ['name', 'cr', 'ac', 'hp', 
                  'str', 'str_mod', 'dex', 'dex_mod', 'con', 'con_mod', 
                  'int','int_mod', 'wis', 'wis_mod', 'cha', 'cha_mod', 
                  'str_save', 'dex_save', 'con_save', 'int_save', 'wis_save', 'cha_save', 
                   'speed', 'size', 'monster_type', 'swim', 'fly', 'climb' ]

df = pd.read_csv(
                file, 
                header = 0, 
                names = columns,
                usecols = useful_columns 
                )
        
df = df.reset_index(drop = True)
#we will add a numeric version of cr level for commodity
df["numeric_cr"] = df.cr.apply(eval)
df.head(5)
# Out:
#                  name    size         monster_type  ac   hp  str  str_mod  \
# 0             Aboleth   Large           Aberration  17  135   21        5
# 1             Acolyte  Medium  Humanoid (any race)  10    9   10        0
# 2  Adult Black Dragon    Huge               Dragon  19  195   23        6
# 3   Adult Blue Dragon    Huge               Dragon  19  225   25        7
# 4  Adult Brass Dragon    Huge               Dragon  18  172   23        6
#
#    dex  dex_mod  con  ...  dex_save  con_save  int_save  wis_save  cha_save  \
# 0    9       -1   15  ...         0         6         8         6         0
# 1   10        0   10  ...         0         0         0         0         0
# 2   14        2   21  ...         7        10         0         6         8
# 3   10        0   23  ...         5        11         0         7         9
# 4   10        0   21  ...         5        10         0         6         8
#
#    speed  swim fly  climb  numeric_cr
# 0     10    40   0      0       10.00
# 1     30     0   0      0        0.25
# 2     40    40  80      0       14.00
# 3     40     0  80      0       16.00
# 4     40     0  80      0       13.00
#
# [5 rows x 29 columns]

# %%
df
# Out:
#                     name    size         monster_type  ac   hp  str  str_mod  \
# 0                Aboleth   Large           Aberration  17  135   21        5
# 1                Acolyte  Medium  Humanoid (any race)  10    9   10        0
# 2     Adult Black Dragon    Huge               Dragon  19  195   23        6
# 3      Adult Blue Dragon    Huge               Dragon  19  225   25        7
# 4     Adult Brass Dragon    Huge               Dragon  18  172   23        6
# ..                   ...     ...                  ...  ..  ...  ...      ...
# 319   Young Green Dragon   Large               Dragon  18  136   19        4
# 320     Young Red Dragon   Large               Dragon  18  178   23        6
# 321  Young Silver Dragon   Large               Dragon  18  168   23        6
# 322   Young White Dragon   Large               Dragon  17  133   18        4
# 323               Zombie  Medium               Undead   8   22   13        1
#
#      dex  dex_mod  con  ...  dex_save  con_save  int_save  wis_save  cha_save  \
# 0      9       -1   15  ...         0         6         8         6         0
# 1     10        0   10  ...         0         0         0         0         0
# 2     14        2   21  ...         7        10         0         6         8
# 3     10        0   23  ...         5        11         0         7         9
# 4     10        0   21  ...         5        10         0         6         8
# ..   ...      ...  ...  ...       ...       ...       ...       ...       ...
# 319   12        1   17  ...         4         6         0         4         5
# 320   10        0   21  ...         4         9         0         4         8
# 321   10        0   21  ...         4         9         0         4         8
# 322   10        0   18  ...         3         7         0         3         4
# 323    6       -2   16  ...         0         0         0         0         0
#
#      speed  swim fly  climb  numeric_cr
# 0       10    40   0      0       10.00
# 1       30     0   0      0        0.25
# 2       40    40  80      0       14.00
# 3       40     0  80      0       16.00
# 4       40     0  80      0       13.00
# ..     ...   ...  ..    ...         ...
# 319     40    40  80      0        8.00
# 320     40     0  80     40       10.00
# 321     40     0  80      0        9.00
# 322     40    40  80      0        6.00
# 323     20     0   0      0        0.25
#
# [324 rows x 29 columns]

# %% [markdown]
# ### 1.2 Error handling

# %% [markdown]
# Nothing ever is perfect: through our study we have found an error on this database. We will try to clean it up.

# %%
df[df["name"] == "Tarrasque"]\
      [['name', 'dex', 'dex_mod', 'dex_save', 'con', 'con_mod', 'con_save']]\
      .style\
      .apply(lambda x: ['background-color: #B2B2B2' if x.values == 30 and x.name == "con" else ''], axis=0)\
      .apply(lambda x: ['background-color: #D1D1D1' if x.values == 1 and x.name == "con_mod" else ''], axis=0)
# Out:
# <style type="text/css">
# #T_ef7c3_row0_col4 {
#   background-color: #B2B2B2;
# }
# #T_ef7c3_row0_col5 {
#   background-color: #D1D1D1;
# }
# </style>
# <table id="T_ef7c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef7c3_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_ef7c3_level0_col1" class="col_heading level0 col1" >dex</th>
#       <th id="T_ef7c3_level0_col2" class="col_heading level0 col2" >dex_mod</th>
#       <th id="T_ef7c3_level0_col3" class="col_heading level0 col3" >dex_save</th>
#       <th id="T_ef7c3_level0_col4" class="col_heading level0 col4" >con</th>
#       <th id="T_ef7c3_level0_col5" class="col_heading level0 col5" >con_mod</th>
#       <th id="T_ef7c3_level0_col6" class="col_heading level0 col6" >con_save</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef7c3_level0_row0" class="row_heading level0 row0" >280</th>
#       <td id="T_ef7c3_row0_col0" class="data row0 col0" >Tarrasque</td>
#       <td id="T_ef7c3_row0_col1" class="data row0 col1" >11</td>
#       <td id="T_ef7c3_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_ef7c3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ef7c3_row0_col4" class="data row0 col4" >30</td>
#       <td id="T_ef7c3_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_ef7c3_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This monster has a con stat of 30, but a mod of 1. Every stat value has a specified modifier, and 30's one is a +10
#
# _(PS: in this table con is the stat, con_mod is the modificator, and con_save is the save when defined by other rules. If this last one is bigger it is used instead of con_mod)_
#
# Lets quickly create a dictionary with the appropriated values

# %%
import math

stats_mods = dict(zip (range(1,31), [-5 + math.floor(x/2) for x in range(1,31)]))

# %% [markdown]
# Lets look for more errors where the stat mod isn't the right one

# %%
for stat in ['str','dex','con','int','wis','cha']:
    stat_mod = stat + "_mod"
    errors = df[ df[stat_mod] != df[stat].apply(lambda x : stats_mods[x]) ].shape[0]
    
    if errors >0:
        print(errors," errors in stat", stat)
# Out:
# 5  errors in stat str
# 1  errors in stat con
# 1  errors in stat cha

# %% [markdown]
# 7 stats mods aren't the good ones. If we would look into the errors we would indeed see there's something going on with stats with a score of 30. Let me skip the search and directly put out the monsters that have an error:

# %%
cols_to_see = ["name", 'str', 'str_mod', 'dex','dex_mod', 
               'con', 'con_mod', 'int', 'int_mod', 
               'wis', 'wis_mod', 'cha', 'cha_mod']

df[df[['str', 'dex', 'con','int', 'wis', 'cha']].eq(30).any(axis=1)][cols_to_see]\
    .style.apply(lambda x: ['background-color: #B2B2B2' if values == 30 else '' for values in x], axis=0)\
    .apply(lambda x: ['background-color: #d1d1d1' if values == 1 else '' for values in x], axis=0)
# Out:
# <style type="text/css">
# #T_09a64_row0_col1, #T_09a64_row1_col1, #T_09a64_row2_col1, #T_09a64_row3_col1, #T_09a64_row4_col11, #T_09a64_row5_col1, #T_09a64_row5_col5 {
#   background-color: #B2B2B2;
# }
# #T_09a64_row0_col2, #T_09a64_row1_col2, #T_09a64_row2_col2, #T_09a64_row3_col2, #T_09a64_row4_col12, #T_09a64_row5_col2, #T_09a64_row5_col6 {
#   background-color: #d1d1d1;
# }
# </style>
# <table id="T_09a64">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09a64_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_09a64_level0_col1" class="col_heading level0 col1" >str</th>
#       <th id="T_09a64_level0_col2" class="col_heading level0 col2" >str_mod</th>
#       <th id="T_09a64_level0_col3" class="col_heading level0 col3" >dex</th>
#       <th id="T_09a64_level0_col4" class="col_heading level0 col4" >dex_mod</th>
#       <th id="T_09a64_level0_col5" class="col_heading level0 col5" >con</th>
#       <th id="T_09a64_level0_col6" class="col_heading level0 col6" >con_mod</th>
#       <th id="T_09a64_level0_col7" class="col_heading level0 col7" >int</th>
#       <th id="T_09a64_level0_col8" class="col_heading level0 col8" >int_mod</th>
#       <th id="T_09a64_level0_col9" class="col_heading level0 col9" >wis</th>
#       <th id="T_09a64_level0_col10" class="col_heading level0 col10" >wis_mod</th>
#       <th id="T_09a64_level0_col11" class="col_heading level0 col11" >cha</th>
#       <th id="T_09a64_level0_col12" class="col_heading level0 col12" >cha_mod</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09a64_level0_row0" class="row_heading level0 row0" >18</th>
#       <td id="T_09a64_row0_col0" class="data row0 col0" >Ancient Gold Dragon</td>
#       <td id="T_09a64_row0_col1" class="data row0 col1" >30</td>
#       <td id="T_09a64_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_09a64_row0_col3" class="data row0 col3" >14</td>
#       <td id="T_09a64_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_09a64_row0_col5" class="data row0 col5" >29</td>
#       <td id="T_09a64_row0_col6" class="data row0 col6" >9</td>
#       <td id="T_09a64_row0_col7" class="data row0 col7" >18</td>
#       <td id="T_09a64_row0_col8" class="data row0 col8" >4</td>
#       <td id="T_09a64_row0_col9" class="data row0 col9" >17</td>
#       <td id="T_09a64_row0_col10" class="data row0 col10" >3</td>
#       <td id="T_09a64_row0_col11" class="data row0 col11" >28</td>
#       <td id="T_09a64_row0_col12" class="data row0 col12" >9</td>
#     </tr>
#     <tr>
#       <th id="T_09a64_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_09a64_row1_col0" class="data row1 col0" >Ancient Red Dragon</td>
#       <td id="T_09a64_row1_col1" class="data row1 col1" >30</td>
#       <td id="T_09a64_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_09a64_row1_col3" class="data row1 col3" >10</td>
#       <td id="T_09a64_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_09a64_row1_col5" class="data row1 col5" >29</td>
#       <td id="T_09a64_row1_col6" class="data row1 col6" >9</td>
#       <td id="T_09a64_row1_col7" class="data row1 col7" >18</td>
#       <td id="T_09a64_row1_col8" class="data row1 col8" >4</td>
#       <td id="T_09a64_row1_col9" class="data row1 col9" >15</td>
#       <td id="T_09a64_row1_col10" class="data row1 col10" >2</td>
#       <td id="T_09a64_row1_col11" class="data row1 col11" >23</td>
#       <td id="T_09a64_row1_col12" class="data row1 col12" >6</td>
#     </tr>
#     <tr>
#       <th id="T_09a64_level0_row2" class="row_heading level0 row2" >21</th>
#       <td id="T_09a64_row2_col0" class="data row2 col0" >Ancient Silver Dragon</td>
#       <td id="T_09a64_row2_col1" class="data row2 col1" >30</td>
#       <td id="T_09a64_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_09a64_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_09a64_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_09a64_row2_col5" class="data row2 col5" >29</td>
#       <td id="T_09a64_row2_col6" class="data row2 col6" >9</td>
#       <td id="T_09a64_row2_col7" class="data row2 col7" >18</td>
#       <td id="T_09a64_row2_col8" class="data row2 col8" >4</td>
#       <td id="T_09a64_row2_col9" class="data row2 col9" >15</td>
#       <td id="T_09a64_row2_col10" class="data row2 col10" >2</td>
#       <td id="T_09a64_row2_col11" class="data row2 col11" >23</td>
#       <td id="T_09a64_row2_col12" class="data row2 col12" >6</td>
#     </tr>
#     <tr>
#       <th id="T_09a64_level0_row3" class="row_heading level0 row3" >181</th>
#       <td id="T_09a64_row3_col0" class="data row3 col0" >Kraken</td>
#       <td id="T_09a64_row3_col1" class="data row3 col1" >30</td>
#       <td id="T_09a64_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_09a64_row3_col3" class="data row3 col3" >11</td>
#       <td id="T_09a64_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_09a64_row3_col5" class="data row3 col5" >25</td>
#       <td id="T_09a64_row3_col6" class="data row3 col6" >7</td>
#       <td id="T_09a64_row3_col7" class="data row3 col7" >22</td>
#       <td id="T_09a64_row3_col8" class="data row3 col8" >6</td>
#       <td id="T_09a64_row3_col9" class="data row3 col9" >18</td>
#       <td id="T_09a64_row3_col10" class="data row3 col10" >4</td>
#       <td id="T_09a64_row3_col11" class="data row3 col11" >20</td>
#       <td id="T_09a64_row3_col12" class="data row3 col12" >5</td>
#     </tr>
#     <tr>
#       <th id="T_09a64_level0_row4" class="row_heading level0 row4" >257</th>
#       <td id="T_09a64_row4_col0" class="data row4 col0" >Solar</td>
#       <td id="T_09a64_row4_col1" class="data row4 col1" >26</td>
#       <td id="T_09a64_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_09a64_row4_col3" class="data row4 col3" >22</td>
#       <td id="T_09a64_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_09a64_row4_col5" class="data row4 col5" >26</td>
#       <td id="T_09a64_row4_col6" class="data row4 col6" >8</td>
#       <td id="T_09a64_row4_col7" class="data row4 col7" >25</td>
#       <td id="T_09a64_row4_col8" class="data row4 col8" >7</td>
#       <td id="T_09a64_row4_col9" class="data row4 col9" >25</td>
#       <td id="T_09a64_row4_col10" class="data row4 col10" >7</td>
#       <td id="T_09a64_row4_col11" class="data row4 col11" >30</td>
#       <td id="T_09a64_row4_col12" class="data row4 col12" >1</td>
#     </tr>
#     <tr>
#       <th id="T_09a64_level0_row5" class="row_heading level0 row5" >280</th>
#       <td id="T_09a64_row5_col0" class="data row5 col0" >Tarrasque</td>
#       <td id="T_09a64_row5_col1" class="data row5 col1" >30</td>
#       <td id="T_09a64_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_09a64_row5_col3" class="data row5 col3" >11</td>
#       <td id="T_09a64_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_09a64_row5_col5" class="data row5 col5" >30</td>
#       <td id="T_09a64_row5_col6" class="data row5 col6" >1</td>
#       <td id="T_09a64_row5_col7" class="data row5 col7" >3</td>
#       <td id="T_09a64_row5_col8" class="data row5 col8" >-4</td>
#       <td id="T_09a64_row5_col9" class="data row5 col9" >11</td>
#       <td id="T_09a64_row5_col10" class="data row5 col10" >0</td>
#       <td id="T_09a64_row5_col11" class="data row5 col11" >11</td>
#       <td id="T_09a64_row5_col12" class="data row5 col12" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It seems like stats with a score of 30 aren't properly passed to a +10 on the stat mod.<br>
# Lets change the errors

# %%
for stat in ['str','dex','con','int','wis','cha']:
    stat_mod = stat + "_mod"
    df[stat_mod] = df[stat].apply(lambda x : stats_mods[x])

# %%
df_styled = df[df[['str', 'dex', 'con','int', 'wis', 'cha']].eq(30).any(axis=1)][cols_to_see]\
    .style.apply(lambda x: ['background-color: #B2B2B2' if values == 30 else '' for values in x], axis=0)\
    .apply(lambda x: ['background-color: #D1D1D1' if values == 10 and "mod" in x.name else '' for values in x], axis=0)
df_styled
# Out:
# <style type="text/css">
# #T_38335_row0_col1, #T_38335_row1_col1, #T_38335_row2_col1, #T_38335_row3_col1, #T_38335_row4_col11, #T_38335_row5_col1, #T_38335_row5_col5 {
#   background-color: #B2B2B2;
# }
# #T_38335_row0_col2, #T_38335_row1_col2, #T_38335_row2_col2, #T_38335_row3_col2, #T_38335_row4_col12, #T_38335_row5_col2, #T_38335_row5_col6 {
#   background-color: #D1D1D1;
# }
# </style>
# <table id="T_38335">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38335_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_38335_level0_col1" class="col_heading level0 col1" >str</th>
#       <th id="T_38335_level0_col2" class="col_heading level0 col2" >str_mod</th>
#       <th id="T_38335_level0_col3" class="col_heading level0 col3" >dex</th>
#       <th id="T_38335_level0_col4" class="col_heading level0 col4" >dex_mod</th>
#       <th id="T_38335_level0_col5" class="col_heading level0 col5" >con</th>
#       <th id="T_38335_level0_col6" class="col_heading level0 col6" >con_mod</th>
#       <th id="T_38335_level0_col7" class="col_heading level0 col7" >int</th>
#       <th id="T_38335_level0_col8" class="col_heading level0 col8" >int_mod</th>
#       <th id="T_38335_level0_col9" class="col_heading level0 col9" >wis</th>
#       <th id="T_38335_level0_col10" class="col_heading level0 col10" >wis_mod</th>
#       <th id="T_38335_level0_col11" class="col_heading level0 col11" >cha</th>
#       <th id="T_38335_level0_col12" class="col_heading level0 col12" >cha_mod</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38335_level0_row0" class="row_heading level0 row0" >18</th>
#       <td id="T_38335_row0_col0" class="data row0 col0" >Ancient Gold Dragon</td>
#       <td id="T_38335_row0_col1" class="data row0 col1" >30</td>
#       <td id="T_38335_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_38335_row0_col3" class="data row0 col3" >14</td>
#       <td id="T_38335_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_38335_row0_col5" class="data row0 col5" >29</td>
#       <td id="T_38335_row0_col6" class="data row0 col6" >9</td>
#       <td id="T_38335_row0_col7" class="data row0 col7" >18</td>
#       <td id="T_38335_row0_col8" class="data row0 col8" >4</td>
#       <td id="T_38335_row0_col9" class="data row0 col9" >17</td>
#       <td id="T_38335_row0_col10" class="data row0 col10" >3</td>
#       <td id="T_38335_row0_col11" class="data row0 col11" >28</td>
#       <td id="T_38335_row0_col12" class="data row0 col12" >9</td>
#     </tr>
#     <tr>
#       <th id="T_38335_level0_row1" class="row_heading level0 row1" >20</th>
#       <td id="T_38335_row1_col0" class="data row1 col0" >Ancient Red Dragon</td>
#       <td id="T_38335_row1_col1" class="data row1 col1" >30</td>
#       <td id="T_38335_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_38335_row1_col3" class="data row1 col3" >10</td>
#       <td id="T_38335_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_38335_row1_col5" class="data row1 col5" >29</td>
#       <td id="T_38335_row1_col6" class="data row1 col6" >9</td>
#       <td id="T_38335_row1_col7" class="data row1 col7" >18</td>
#       <td id="T_38335_row1_col8" class="data row1 col8" >4</td>
#       <td id="T_38335_row1_col9" class="data row1 col9" >15</td>
#       <td id="T_38335_row1_col10" class="data row1 col10" >2</td>
#       <td id="T_38335_row1_col11" class="data row1 col11" >23</td>
#       <td id="T_38335_row1_col12" class="data row1 col12" >6</td>
#     </tr>
#     <tr>
#       <th id="T_38335_level0_row2" class="row_heading level0 row2" >21</th>
#       <td id="T_38335_row2_col0" class="data row2 col0" >Ancient Silver Dragon</td>
#       <td id="T_38335_row2_col1" class="data row2 col1" >30</td>
#       <td id="T_38335_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_38335_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_38335_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_38335_row2_col5" class="data row2 col5" >29</td>
#       <td id="T_38335_row2_col6" class="data row2 col6" >9</td>
#       <td id="T_38335_row2_col7" class="data row2 col7" >18</td>
#       <td id="T_38335_row2_col8" class="data row2 col8" >4</td>
#       <td id="T_38335_row2_col9" class="data row2 col9" >15</td>
#       <td id="T_38335_row2_col10" class="data row2 col10" >2</td>
#       <td id="T_38335_row2_col11" class="data row2 col11" >23</td>
#       <td id="T_38335_row2_col12" class="data row2 col12" >6</td>
#     </tr>
#     <tr>
#       <th id="T_38335_level0_row3" class="row_heading level0 row3" >181</th>
#       <td id="T_38335_row3_col0" class="data row3 col0" >Kraken</td>
#       <td id="T_38335_row3_col1" class="data row3 col1" >30</td>
#       <td id="T_38335_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_38335_row3_col3" class="data row3 col3" >11</td>
#       <td id="T_38335_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_38335_row3_col5" class="data row3 col5" >25</td>
#       <td id="T_38335_row3_col6" class="data row3 col6" >7</td>
#       <td id="T_38335_row3_col7" class="data row3 col7" >22</td>
#       <td id="T_38335_row3_col8" class="data row3 col8" >6</td>
#       <td id="T_38335_row3_col9" class="data row3 col9" >18</td>
#       <td id="T_38335_row3_col10" class="data row3 col10" >4</td>
#       <td id="T_38335_row3_col11" class="data row3 col11" >20</td>
#       <td id="T_38335_row3_col12" class="data row3 col12" >5</td>
#     </tr>
#     <tr>
#       <th id="T_38335_level0_row4" class="row_heading level0 row4" >257</th>
#       <td id="T_38335_row4_col0" class="data row4 col0" >Solar</td>
#       <td id="T_38335_row4_col1" class="data row4 col1" >26</td>
#       <td id="T_38335_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_38335_row4_col3" class="data row4 col3" >22</td>
#       <td id="T_38335_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_38335_row4_col5" class="data row4 col5" >26</td>
#       <td id="T_38335_row4_col6" class="data row4 col6" >8</td>
#       <td id="T_38335_row4_col7" class="data row4 col7" >25</td>
#       <td id="T_38335_row4_col8" class="data row4 col8" >7</td>
#       <td id="T_38335_row4_col9" class="data row4 col9" >25</td>
#       <td id="T_38335_row4_col10" class="data row4 col10" >7</td>
#       <td id="T_38335_row4_col11" class="data row4 col11" >30</td>
#       <td id="T_38335_row4_col12" class="data row4 col12" >10</td>
#     </tr>
#     <tr>
#       <th id="T_38335_level0_row5" class="row_heading level0 row5" >280</th>
#       <td id="T_38335_row5_col0" class="data row5 col0" >Tarrasque</td>
#       <td id="T_38335_row5_col1" class="data row5 col1" >30</td>
#       <td id="T_38335_row5_col2" class="data row5 col2" >10</td>
#       <td id="T_38335_row5_col3" class="data row5 col3" >11</td>
#       <td id="T_38335_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_38335_row5_col5" class="data row5 col5" >30</td>
#       <td id="T_38335_row5_col6" class="data row5 col6" >10</td>
#       <td id="T_38335_row5_col7" class="data row5 col7" >3</td>
#       <td id="T_38335_row5_col8" class="data row5 col8" >-4</td>
#       <td id="T_38335_row5_col9" class="data row5 col9" >11</td>
#       <td id="T_38335_row5_col10" class="data row5 col10" >0</td>
#       <td id="T_38335_row5_col11" class="data row5 col11" >11</td>
#       <td id="T_38335_row5_col12" class="data row5 col12" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# fixed!

# %%
df.to_csv("monsters.csv", index=False)
